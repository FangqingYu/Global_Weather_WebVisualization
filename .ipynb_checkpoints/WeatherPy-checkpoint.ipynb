# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

from api_keys import api_key

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

units = "metric"

# %%
# List for holding lat_lngs and cities

cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Create tuples of lats and lngs
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    # lat_lng[0] - latitude
    # lat_lng[1] - longitude
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 764

# %%
cities_df = pd.DataFrame({"City": cities})
cities_df['Cloudiness']= ""
cities_df['Country']= ""
cities_df['Date']= ""
cities_df['Humidity']= ""
cities_df['Lat']= ""
cities_df['Lng']= ""
cities_df['Max Temp']= ""
cities_df['Wind Speed']= ""

cities_df.head()
# Out:
#            City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0         airai
# 1    high level
# 2        anadyr
# 3       bubaque
# 4  san patricio

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?appid={0}&q={1}&units={2}"
base_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid={0}&q={1}&units={2}'

# %%
for index, row in cities_df.iterrows():
    city_url = base_url.format(api_key, row['City'], units)
    city_request = requests.get(city_url).json()
    
    try:
        
        cities_df.loc[index, 'Cloudiness'] = city_request['clouds']['all']
        cities_df.loc[index, 'Country'] = city_request['sys']['country']
        cities_df.loc[index, 'Date'] = city_request['dt']
        cities_df.loc[index, 'Humidity'] = city_request['main']['humidity']
        cities_df.loc[index, 'Lat'] = city_request['coord']['lat']
        cities_df.loc[index, 'Lng'] = city_request['coord']['lon']
        cities_df.loc[index, 'Max Temp'] = city_request['main']['temp_max']
        cities_df.loc[index, 'Wind Speed'] = city_request['wind']['speed']
        
        print("Processing Record " + str(index+1) + " | " + str(row['City']))
   
    except(KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Processing Record 1 | airai
# Processing Record 2 | high level
# Processing Record 3 | anadyr
# Processing Record 4 | bubaque
# Processing Record 5 | san patricio
# Processing Record 6 | mataura
# Processing Record 7 | alta floresta
# Processing Record 8 | albany
# Processing Record 9 | saint-philippe
# Processing Record 10 | zyryanovsk
# Processing Record 11 | hilo
# Processing Record 12 | butaritari
# Processing Record 13 | tasiilaq
# City not found. Skipping...
# Processing Record 15 | lavrentiya
# Processing Record 16 | barrow
# Processing Record 17 | punta arenas
# Processing Record 18 | hermanus
# Processing Record 19 | nadym
# Processing Record 20 | ancud
# Processing Record 21 | ushuaia
# Processing Record 22 | roald
# Processing Record 23 | georgetown
# Processing Record 24 | avarua
# Processing Record 25 | souillac
# Processing Record 26 | carnarvon
# Processing Record 27 | waipawa
# Processing Record 28 | puerto madryn
# Processing Record 29 | rikitea
# City not found. Skipping...
# Processing Record 31 | port elizabeth
# Processing Record 32 | busselton
# Processing Record 33 | lagoa
# Processing Record 34 | jamestown
# Processing Record 35 | abu kamal
# Processing Record 36 | ustrzyki dolne
# City not found. Skipping...
# Processing Record 38 | lebu
# Processing Record 39 | bluff
# City not found. Skipping...
# Processing Record 41 | thompson
# Processing Record 42 | meylan
# City not found. Skipping...
# Processing Record 44 | puerto narino
# Processing Record 45 | lorengau
# Processing Record 46 | tuktoyaktuk
# Processing Record 47 | kruisfontein
# Processing Record 48 | kabanjahe
# City not found. Skipping...
# Processing Record 50 | kodiak
# Processing Record 51 | mao
# Processing Record 52 | yellowknife
# Processing Record 53 | omsukchan
# Processing Record 54 | san policarpo
# Processing Record 55 | nikolskoye
# Processing Record 56 | kyshtovka
# Processing Record 57 | constitucion
# Processing Record 58 | kankan
# Processing Record 59 | new norfolk
# Processing Record 60 | arman
# Processing Record 61 | cockburn town
# City not found. Skipping...
# Processing Record 63 | cidreira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 66 | magalia
# Processing Record 67 | gujrat
# Processing Record 68 | nyrob
# Processing Record 69 | bilibino
# Processing Record 70 | wangaratta
# Processing Record 71 | acajutla
# Processing Record 72 | mama
# Processing Record 73 | yumen
# Processing Record 74 | bredasdorp
# Processing Record 75 | karpogory
# Processing Record 76 | narsaq
# Processing Record 77 | candelaria
# Processing Record 78 | hithadhoo
# Processing Record 79 | ushtobe
# Processing Record 80 | sao joao da barra
# Processing Record 81 | ostrovnoy
# Processing Record 82 | castro
# Processing Record 83 | coquimbo
# Processing Record 84 | puerto ayora
# City not found. Skipping...
# Processing Record 86 | atuona
# Processing Record 87 | bjornevatn
# Processing Record 88 | klaksvik
# Processing Record 89 | cherskiy
# Processing Record 90 | araouane
# Processing Record 91 | chuy
# Processing Record 92 | leningradskiy
# Processing Record 93 | ntcheu
# Processing Record 94 | kieta
# Processing Record 95 | boa vista
# Processing Record 96 | kozhva
# Processing Record 97 | menongue
# Processing Record 98 | husavik
# Processing Record 99 | egvekinot
# Processing Record 100 | vila velha
# Processing Record 101 | vaini
# Processing Record 102 | faanui
# Processing Record 103 | seoul
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 106 | bandarbeyla
# Processing Record 107 | laramie
# Processing Record 108 | cabo san lucas
# Processing Record 109 | bilma
# Processing Record 110 | mar del plata
# Processing Record 111 | kavieng
# City not found. Skipping...
# Processing Record 113 | zhezkazgan
# Processing Record 114 | whitehorse
# Processing Record 115 | mantua
# Processing Record 116 | karangasem
# Processing Record 117 | east london
# Processing Record 118 | bethel
# Processing Record 119 | severo-kurilsk
# Processing Record 120 | san juan del sur
# Processing Record 121 | bud
# Processing Record 122 | cacule
# City not found. Skipping...
# Processing Record 124 | kimbe
# Processing Record 125 | dikson
# Processing Record 126 | usoke
# City not found. Skipping...
# Processing Record 128 | quatre cocos
# Processing Record 129 | manicore
# Processing Record 130 | komsomolskiy
# Processing Record 131 | bereda
# Processing Record 132 | kelvington
# Processing Record 133 | tuatapere
# Processing Record 134 | semnan
# City not found. Skipping...
# Processing Record 136 | magocs
# City not found. Skipping...
# Processing Record 138 | rio grande
# Processing Record 139 | sibolga
# Processing Record 140 | faya
# Processing Record 141 | sobolevo
# Processing Record 142 | gawler
# Processing Record 143 | dingle
# Processing Record 144 | maracacume
# Processing Record 145 | saint-joseph
# Processing Record 146 | copiapo
# Processing Record 147 | leuwiliang
# City not found. Skipping...
# Processing Record 149 | ponta do sol
# Processing Record 150 | soe
# Processing Record 151 | cape town
# Processing Record 152 | vestmannaeyjar
# Processing Record 153 | san nicolas
# Processing Record 154 | broome
# Processing Record 155 | pandan
# Processing Record 156 | port alfred
# City not found. Skipping...
# Processing Record 158 | altay
# Processing Record 159 | bartica
# Processing Record 160 | araruama
# Processing Record 161 | mahebourg
# City not found. Skipping...
# Processing Record 163 | hasaki
# Processing Record 164 | otjiwarongo
# Processing Record 165 | rodeo
# Processing Record 166 | khatanga
# Processing Record 167 | krasnoarmeysk
# Processing Record 168 | saskylakh
# Processing Record 169 | praia da vitoria
# Processing Record 170 | margate
# Processing Record 171 | hobart
# City not found. Skipping...
# Processing Record 173 | luena
# Processing Record 174 | ode
# Processing Record 175 | mirnyy
# City not found. Skipping...
# Processing Record 177 | geraldton
# Processing Record 178 | ribeira grande
# Processing Record 179 | wajid
# Processing Record 180 | grand baie
# Processing Record 181 | kupang
# Processing Record 182 | pisco
# Processing Record 183 | saldanha
# Processing Record 184 | kapaa
# Processing Record 185 | laguna
# Processing Record 186 | cuenca
# Processing Record 187 | lazaro cardenas
# Processing Record 188 | ekimchan
# Processing Record 189 | manokwari
# Processing Record 190 | victoria
# Processing Record 191 | los llanos de aridane
# Processing Record 192 | novouzensk
# Processing Record 193 | tignere
# Processing Record 194 | upernavik
# Processing Record 195 | iqaluit
# Processing Record 196 | marsassoum
# Processing Record 197 | tiksi
# Processing Record 198 | nouadhibou
# Processing Record 199 | tha bo
# Processing Record 200 | emba
# Processing Record 201 | posse
# Processing Record 202 | provideniya
# Processing Record 203 | cayenne
# Processing Record 204 | dawei
# City not found. Skipping...
# Processing Record 206 | grahamstown
# Processing Record 207 | gigmoto
# Processing Record 208 | codrington
# Processing Record 209 | san juan
# Processing Record 210 | nara
# Processing Record 211 | evensk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 214 | lensk
# Processing Record 215 | bukene
# Processing Record 216 | lompoc
# Processing Record 217 | ciudad ojeda
# Processing Record 218 | te anau
# Processing Record 219 | hofn
# Processing Record 220 | laurel
# City not found. Skipping...
# Processing Record 222 | norman wells
# Processing Record 223 | kaihua
# Processing Record 224 | guano
# Processing Record 225 | exaplatanos
# Processing Record 226 | eydhafushi
# Processing Record 227 | chapais
# Processing Record 228 | dengfeng
# Processing Record 229 | tongzi
# Processing Record 230 | sitka
# Processing Record 231 | porto novo
# Processing Record 232 | grindavik
# City not found. Skipping...
# Processing Record 234 | mackay
# Processing Record 235 | matara
# Processing Record 236 | hearst
# Processing Record 237 | dzerzhinsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 240 | chicama
# Processing Record 241 | bad munstereifel
# City not found. Skipping...
# Processing Record 243 | qingdao
# City not found. Skipping...
# Processing Record 245 | qinzhou
# Processing Record 246 | vardo
# Processing Record 247 | hobyo
# Processing Record 248 | qaanaaq
# Processing Record 249 | grand bend
# Processing Record 250 | itoman
# Processing Record 251 | bow island
# Processing Record 252 | kaduna
# Processing Record 253 | labuan
# Processing Record 254 | paita
# Processing Record 255 | trincomalee
# Processing Record 256 | vitina
# Processing Record 257 | zwedru
# Processing Record 258 | fare
# Processing Record 259 | haines junction
# Processing Record 260 | burnie
# City not found. Skipping...
# Processing Record 262 | auki
# Processing Record 263 | miri
# Processing Record 264 | martigny
# Processing Record 265 | salinopolis
# Processing Record 266 | fenoarivo atsinanana
# Processing Record 267 | imphal
# Processing Record 268 | gat
# Processing Record 269 | hualmay
# Processing Record 270 | ramanuj ganj
# Processing Record 271 | paka
# Processing Record 272 | bage
# Processing Record 273 | grand gaube
# Processing Record 274 | leshukonskoye
# Processing Record 275 | rajapolah
# Processing Record 276 | pimenta bueno
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 279 | noumea
# Processing Record 280 | kita
# Processing Record 281 | turukhansk
# Processing Record 282 | kediri
# City not found. Skipping...
# Processing Record 284 | izvestkovyy
# Processing Record 285 | dudinka
# Processing Record 286 | salamiyah
# Processing Record 287 | zhigansk
# Processing Record 288 | walvis bay
# Processing Record 289 | harper
# Processing Record 290 | port hardy
# Processing Record 291 | pudem
# Processing Record 292 | forest
# Processing Record 293 | levokumskoye
# Processing Record 294 | kaitangata
# Processing Record 295 | banjar
# City not found. Skipping...
# Processing Record 297 | deming
# Processing Record 298 | mount gambier
# Processing Record 299 | luderitz
# Processing Record 300 | suibara
# Processing Record 301 | olinda
# Processing Record 302 | vila franca do campo
# Processing Record 303 | kazerun
# City not found. Skipping...
# Processing Record 305 | mangrol
# Processing Record 306 | nola
# Processing Record 307 | beloha
# Processing Record 308 | buraydah
# Processing Record 309 | stromness
# Processing Record 310 | tabou
# Processing Record 311 | encheng
# Processing Record 312 | zhangjiakou
# City not found. Skipping...
# Processing Record 314 | chokurdakh
# Processing Record 315 | trelew
# Processing Record 316 | iskateley
# Processing Record 317 | half moon bay
# Processing Record 318 | ust-ishim
# Processing Record 319 | aykhal
# Processing Record 320 | nome
# Processing Record 321 | sao gabriel da cachoeira
# Processing Record 322 | benguela
# Processing Record 323 | sayyan
# Processing Record 324 | vieste
# Processing Record 325 | mayor pablo lagerenza
# Processing Record 326 | okhotsk
# Processing Record 327 | alpena
# City not found. Skipping...
# Processing Record 329 | abeche
# Processing Record 330 | inhambane
# Processing Record 331 | el angel
# Processing Record 332 | biak
# Processing Record 333 | mvomero
# City not found. Skipping...
# Processing Record 335 | manaure
# Processing Record 336 | alice springs
# Processing Record 337 | arraial do cabo
# Processing Record 338 | baruun-urt
# Processing Record 339 | saint george
# Processing Record 340 | tocopilla
# Processing Record 341 | labuhan
# Processing Record 342 | san felipe
# Processing Record 343 | bathsheba
# Processing Record 344 | palmer
# Processing Record 345 | dukat
# Processing Record 346 | maragogi
# Processing Record 347 | polyarnyy
# Processing Record 348 | tautira
# Processing Record 349 | ixtapa
# Processing Record 350 | paamiut
# Processing Record 351 | ahipara
# Processing Record 352 | nicoya
# Processing Record 353 | yaring
# Processing Record 354 | kichera
# Processing Record 355 | oinoi
# Processing Record 356 | morro bay
# Processing Record 357 | sorland
# Processing Record 358 | buin
# Processing Record 359 | mulege
# Processing Record 360 | emerald
# Processing Record 361 | sabang
# Processing Record 362 | bani walid
# Processing Record 363 | centralia
# Processing Record 364 | la ronge
# Processing Record 365 | soto la marina
# City not found. Skipping...
# Processing Record 367 | binghamton
# Processing Record 368 | camacari
# Processing Record 369 | togur
# Processing Record 370 | gorodishche
# Processing Record 371 | colares
# Processing Record 372 | sapa
# Processing Record 373 | gladstone
# Processing Record 374 | sola
# Processing Record 375 | bisira
# Processing Record 376 | boundiali
# Processing Record 377 | kununurra
# Processing Record 378 | bambous virieux
# Processing Record 379 | barinas
# City not found. Skipping...
# Processing Record 381 | katobu
# Processing Record 382 | kangaatsiaq
# Processing Record 383 | esperance
# Processing Record 384 | natal
# Processing Record 385 | daitari
# Processing Record 386 | aklavik
# Processing Record 387 | peleduy
# Processing Record 388 | sabha
# Processing Record 389 | kudahuvadhoo
# Processing Record 390 | rincon
# Processing Record 391 | ilulissat
# Processing Record 392 | penalva
# Processing Record 393 | campoverde
# Processing Record 394 | kysyl-syr
# Processing Record 395 | zhigalovo
# Processing Record 396 | meulaboh
# Processing Record 397 | pevek
# Processing Record 398 | yerbogachen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 401 | cap malheureux
# Processing Record 402 | hamilton
# Processing Record 403 | sambava
# Processing Record 404 | matamoros
# Processing Record 405 | kathmandu
# Processing Record 406 | tingi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 409 | isangel
# Processing Record 410 | guanica
# Processing Record 411 | guna
# Processing Record 412 | vanimo
# Processing Record 413 | torbay
# Processing Record 414 | champerico
# Processing Record 415 | sinnamary
# Processing Record 416 | kanye
# Processing Record 417 | kutum
# Processing Record 418 | riyadh
# Processing Record 419 | dwarka
# Processing Record 420 | belmonte
# Processing Record 421 | huixtla
# Processing Record 422 | banda aceh
# Processing Record 423 | vuktyl
# Processing Record 424 | salalah
# Processing Record 425 | esso
# Processing Record 426 | yaan
# Processing Record 427 | foldeak
# Processing Record 428 | poum
# Processing Record 429 | kloulklubed
# Processing Record 430 | fuyu
# Processing Record 431 | anekal
# Processing Record 432 | victoria point
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 436 | soyo
# Processing Record 437 | samfya
# Processing Record 438 | camacha
# Processing Record 439 | port macquarie
# Processing Record 440 | pak chong
# Processing Record 441 | panguna
# Processing Record 442 | boyolangu
# Processing Record 443 | yangambi
# Processing Record 444 | voh
# Processing Record 445 | venice
# Processing Record 446 | helena
# Processing Record 447 | vao
# Processing Record 448 | mehamn
# Processing Record 449 | marolambo
# Processing Record 450 | kawalu
# Processing Record 451 | oussouye
# Processing Record 452 | puerto escondido
# Processing Record 453 | lucapa
# Processing Record 454 | negombo
# Processing Record 455 | charters towers
# Processing Record 456 | jacqueville
# Processing Record 457 | saint-pierre
# Processing Record 458 | kargala
# Processing Record 459 | pinerolo
# Processing Record 460 | custodia
# Processing Record 461 | medicine hat
# Processing Record 462 | marsa matruh
# Processing Record 463 | agara
# Processing Record 464 | pacifica
# Processing Record 465 | maniitsoq
# Processing Record 466 | vilcun
# Processing Record 467 | rawson
# Processing Record 468 | nemuro
# Processing Record 469 | balkanabat
# Processing Record 470 | skjervoy
# Processing Record 471 | kahului
# Processing Record 472 | tomatlan
# Processing Record 473 | itarema
# Processing Record 474 | tucumcari
# Processing Record 475 | road town
# Processing Record 476 | gbarnga
# Processing Record 477 | vanavara
# Processing Record 478 | arcachon
# Processing Record 479 | touros
# Processing Record 480 | wagga wagga
# Processing Record 481 | bulungu
# Processing Record 482 | san cristobal
# Processing Record 483 | livingston
# Processing Record 484 | kalabo
# City not found. Skipping...
# Processing Record 486 | tilichiki
# Processing Record 487 | mumbwa
# Processing Record 488 | isla mujeres
# Processing Record 489 | tera
# Processing Record 490 | wamba
# Processing Record 491 | ler
# Processing Record 492 | katangli
# Processing Record 493 | marrakesh
# Processing Record 494 | kinsale
# City not found. Skipping...
# Processing Record 496 | padang
# Processing Record 497 | kibaya
# Processing Record 498 | taoudenni
# Processing Record 499 | nantucket
# Processing Record 500 | buala
# Processing Record 501 | kavaratti
# Processing Record 502 | atar
# Processing Record 503 | peruibe
# Processing Record 504 | grand-santi
# Processing Record 505 | bowen
# Processing Record 506 | khorramshahr
# Processing Record 507 | tsivilsk
# Processing Record 508 | lucea
# Processing Record 509 | roma
# Processing Record 510 | leh
# City not found. Skipping...
# Processing Record 512 | labytnangi
# Processing Record 513 | lumeje
# Processing Record 514 | canmore
# Processing Record 515 | lima
# Processing Record 516 | lavumisa
# Processing Record 517 | golden gate
# Processing Record 518 | vrangel
# Processing Record 519 | porbandar
# Processing Record 520 | iralaya
# Processing Record 521 | glyadyanskoye
# Processing Record 522 | vila do maio
# Processing Record 523 | arlit
# Processing Record 524 | zaraza
# City not found. Skipping...
# Processing Record 526 | waddan
# Processing Record 527 | kulhudhuffushi
# Processing Record 528 | tecoanapa
# Processing Record 529 | damietta
# Processing Record 530 | ruthin
# City not found. Skipping...
# Processing Record 532 | canchungo
# Processing Record 533 | smidovich
# Processing Record 534 | veshenskaya
# Processing Record 535 | moroni
# Processing Record 536 | wladyslawowo
# Processing Record 537 | brentwood
# City not found. Skipping...
# Processing Record 539 | kapit
# Processing Record 540 | harnai
# Processing Record 541 | dombarovskiy
# Processing Record 542 | taywarah
# Processing Record 543 | fukue
# City not found. Skipping...
# Processing Record 545 | edson
# Processing Record 546 | elko
# Processing Record 547 | ceuta
# Processing Record 548 | micheweni
# Processing Record 549 | gayny
# Processing Record 550 | antalaha
# Processing Record 551 | puerto carreno
# Processing Record 552 | kamensk-uralskiy
# Processing Record 553 | rahuri
# Processing Record 554 | pontianak
# Processing Record 555 | ukiah
# Processing Record 556 | semey
# Processing Record 557 | suntar
# Processing Record 558 | clyde river
# Processing Record 559 | fasa
# Processing Record 560 | tetouan
# Processing Record 561 | willmar
# Processing Record 562 | pleshanovo
# Processing Record 563 | coihaique
# Processing Record 564 | dessau
# Processing Record 565 | barcelos
# Processing Record 566 | bujumbura
# Processing Record 567 | aripuana
# Processing Record 568 | portland
# Processing Record 569 | goderich
# Processing Record 570 | kaduqli
# Processing Record 571 | svetlaya
# Processing Record 572 | koslan
# Processing Record 573 | gazimurskiy zavod
# Processing Record 574 | fortuna
# Processing Record 575 | deputatskiy
# Processing Record 576 | okha
# Processing Record 577 | huarmey
# City not found. Skipping...
# Processing Record 579 | monroe
# Processing Record 580 | hambantota
# Processing Record 581 | rio gallegos
# Processing Record 582 | chapeco
# Processing Record 583 | merauke
# Processing Record 584 | zhanaozen
# Processing Record 585 | carauari
# Processing Record 586 | brae
# Processing Record 587 | shelopugino
# Processing Record 588 | yuncheng
# Processing Record 589 | sao filipe
# Processing Record 590 | sheregesh
# Processing Record 591 | beira
# Processing Record 592 | popondetta
# Processing Record 593 | sergiyevsk
# City not found. Skipping...
# Processing Record 595 | semiletka
# Processing Record 596 | pierre
# Processing Record 597 | kenora
# Processing Record 598 | yanam
# Processing Record 599 | juneau
# Processing Record 600 | yashkul
# Processing Record 601 | dolores
# Processing Record 602 | hay river
# Processing Record 603 | matay
# Processing Record 604 | guerrero negro
# Processing Record 605 | luang prabang
# Processing Record 606 | onega
# Processing Record 607 | akdepe
# Processing Record 608 | bethlehem
# Processing Record 609 | roebourne
# City not found. Skipping...
# Processing Record 611 | katsuura
# Processing Record 612 | chimbote
# Processing Record 613 | namibe
# Processing Record 614 | longyearbyen
# Processing Record 615 | ulaangom
# Processing Record 616 | talnakh
# Processing Record 617 | north platte
# Processing Record 618 | verkhoyansk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 621 | port blair
# Processing Record 622 | hirara
# Processing Record 623 | were ilu
# Processing Record 624 | aksu
# Processing Record 625 | mazamari
# City not found. Skipping...
# Processing Record 627 | almeirim
# Processing Record 628 | vangaindrano
# Processing Record 629 | xining
# Processing Record 630 | saint anthony
# Processing Record 631 | muros
# Processing Record 632 | lewisburg
# Processing Record 633 | asyut
# Processing Record 634 | mana
# Processing Record 635 | balkhash
# City not found. Skipping...
# Processing Record 637 | the valley
# Processing Record 638 | teguise
# Processing Record 639 | mabaruma
# Processing Record 640 | mamallapuram
# Processing Record 641 | srednekolymsk
# Processing Record 642 | broken hill
# Processing Record 643 | fillan
# Processing Record 644 | birao
# Processing Record 645 | tagusao
# City not found. Skipping...
# Processing Record 647 | santiago
# Processing Record 648 | show low
# Processing Record 649 | lecce
# Processing Record 650 | ugoofaaru
# Processing Record 651 | cururupu
# Processing Record 652 | fort nelson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 655 | synya
# Processing Record 656 | tabas
# Processing Record 657 | nanortalik
# Processing Record 658 | benghazi
# Processing Record 659 | knysna
# Processing Record 660 | rosario
# Processing Record 661 | bantou
# Processing Record 662 | booue
# Processing Record 663 | santa isabel do rio negro
# Processing Record 664 | sungairaya
# Processing Record 665 | sangar
# Processing Record 666 | tigil
# Processing Record 667 | kariba
# Processing Record 668 | yulara
# Processing Record 669 | la rioja
# City not found. Skipping...
# Processing Record 671 | la libertad
# Processing Record 672 | mitsamiouli
# Processing Record 673 | sur
# Processing Record 674 | beringovskiy
# Processing Record 675 | businga
# Processing Record 676 | itanagar
# Processing Record 677 | ponta delgada
# Processing Record 678 | amuntai
# Processing Record 679 | libreville
# Processing Record 680 | honiara
# Processing Record 681 | impfondo
# Processing Record 682 | fairbanks
# City not found. Skipping...
# Processing Record 684 | nyurba
# Processing Record 685 | comodoro rivadavia
# Processing Record 686 | pithoro
# Processing Record 687 | samoded
# Processing Record 688 | jumla
# Processing Record 689 | prado
# Processing Record 690 | piracanjuba
# City not found. Skipping...
# Processing Record 692 | floriano
# Processing Record 693 | coahuayana
# Processing Record 694 | fuling
# Processing Record 695 | lethem
# Processing Record 696 | sao jose da coroa grande
# Processing Record 697 | biu
# Processing Record 698 | mayumba
# Processing Record 699 | new deer
# Processing Record 700 | jiwani
# Processing Record 701 | marawi
# Processing Record 702 | khash
# Processing Record 703 | saint-augustin
# Processing Record 704 | arkhara
# Processing Record 705 | aurangabad
# Processing Record 706 | rocha
# Processing Record 707 | belyy yar
# Processing Record 708 | maldonado
# City not found. Skipping...
# Processing Record 710 | guangyuan
# Processing Record 711 | ovruch
# Processing Record 712 | taft
# City not found. Skipping...
# Processing Record 714 | lengshuijiang
# City not found. Skipping...
# Processing Record 716 | quesnel
# Processing Record 717 | shiraz
# Processing Record 718 | pemberton
# Processing Record 719 | richards bay
# Processing Record 720 | sawakin
# Processing Record 721 | dandong
# Processing Record 722 | sompeta
# Processing Record 723 | caravelas
# Processing Record 724 | limon
# Processing Record 725 | aitape
# Processing Record 726 | fowa
# Processing Record 727 | ilo
# Processing Record 728 | rapid city
# Processing Record 729 | batsfjord
# Processing Record 730 | khilok
# City not found. Skipping...
# Processing Record 732 | kadoma
# Processing Record 733 | point pedro
# City not found. Skipping...
# Processing Record 735 | maceio
# Processing Record 736 | ketchikan
# Processing Record 737 | jiuquan
# Processing Record 738 | acapulco
# Processing Record 739 | ahuimanu
# Processing Record 740 | oyek
# Processing Record 741 | villarrobledo
# Processing Record 742 | cabedelo
# Processing Record 743 | neryungri
# Processing Record 744 | tupancireta
# Processing Record 745 | college
# Processing Record 746 | mombetsu
# Processing Record 747 | christiansburg
# Processing Record 748 | khovu-aksy
# Processing Record 749 | oktyabrskiy
# Processing Record 750 | lagunas
# City not found. Skipping...
# Processing Record 752 | campbell river
# Processing Record 753 | khani
# Processing Record 754 | lanivtsi
# Processing Record 755 | djenne
# Processing Record 756 | bintulu
# Processing Record 757 | santa cruz cabralia
# City not found. Skipping...
# Processing Record 759 | san rafael
# Processing Record 760 | zonguldak
# Processing Record 761 | yulin
# Processing Record 762 | suzdal
# Processing Record 763 | healdsburg
# Processing Record 764 | ilhabela

# %%
cities_df.count()
# Out:
# City          764
# Cloudiness    764
# Country       764
# Date          764
# Humidity      764
# Lat           764
# Lng           764
# Max Temp      764
# Wind Speed    764
# dtype: int64

# %%
cities_df = cities_df.dropna(how='any')
cities_df.count()
# Out:
# City          764
# Cloudiness    764
# Country       764
# Date          764
# Humidity      764
# Lat           764
# Lng           764
# Max Temp      764
# Wind Speed    764
# dtype: int64

# %%
cities_df.head()
cities_df.to_csv(output_data_file)

# %%
for column in ['Cloudiness', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']:
    cities_df[column] = pd.to_numeric(cities_df[column])
    #print(type(cities_df[column][1]))

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.set_title("City Latitude v.s. Max Temperature (01/05/2019)", fontsize=18)
ax.scatter(cities_df['Lat'], 
            cities_df['Max Temp'], 
            marker='o', 
            facecolor='mediumblue',
            edgecolor='black',
            s=40, 
            alpha=0.7)
ax.set_xlabel("Latitude", fontsize=14)
ax.set_ylabel("Max Temperature (C)", fontsize=14)
ax.set_xlim(-80, 100)
ax.set_ylim(-60,60)
ax.grid(color="white")
ax.set_facecolor(color="lavender")

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
# Conclusion:
# The plot shows that maximum temperature reaches higher around 0 degress laitude or the equator.

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.set_title("City Latitude v.s. Humidity (01/05/2019)", fontsize=18)
ax.scatter(cities_df['Lat'], 
            cities_df['Humidity'], 
            marker='o', 
            facecolor='mediumblue',
            edgecolor='black',
            s=40, 
            alpha=0.7)
ax.set_xlabel("Latitude", fontsize=14)
ax.set_ylabel("Humidity (%)", fontsize=14)
ax.set_xlim(-80, 100)
ax.set_ylim(-0,120)
ax.grid(color="white")
ax.set_facecolor(color="lavender")

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
# Conclusion:
# According to plot, humidity level tends to be uniformly higher right around the equator and varies more as we move away from it.

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.set_title("City Latitude v.s. Cloudiness (01/05/2019)", fontsize=18)
ax.scatter(cities_df['Lat'], 
            cities_df['Cloudiness'], 
            marker='o', 
            facecolor='mediumblue',
            edgecolor='black',
            s=40, 
            alpha=0.7)
ax.set_xlabel("Latitude", fontsize=14)
ax.set_ylabel("Cloudiness (%)", fontsize=14)
ax.set_xlim(-80, 100)
ax.set_ylim(-20,120)
ax.grid(color="white")
ax.set_facecolor(color="lavender")

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
# Conclusion:
# The plot shows that the amount of clouds tends to be slightly more varied around and equater, but the difference is not very obvious.

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.set_title("City Latitude v.s. Wind Speed (01/05/2019)", fontsize=18)
ax.scatter(cities_df['Lat'], 
            cities_df['Wind Speed'], 
            marker='o', 
            facecolor='mediumblue',
            edgecolor='black',
            s=40, 
            alpha=0.7)
ax.set_xlabel("Latitude", fontsize=14)
ax.set_ylabel("Cloudiness (%)", fontsize=14)
ax.set_xlim(-80, 100)
ax.set_ylim(-6,40)
ax.grid(color="white")
ax.set_facecolor(color="lavender")

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
# Conclusion: 
# According to the plot, wind is slower around the equator and picks up more speed as we move further away from it.

# %%
city_url = base_url.format(api_key, cities_df['City'][2], units)
city_request = requests.get(city_url).json()

print(json.dumps(city_request, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -19.25,
#         "lon": 17.72
#     },
#     "dt": 1541404800,
#     "id": 3352593,
#     "main": {
#         "humidity": 36,
#         "pressure": 1021,
#         "temp": 27,
#         "temp_max": 27,
#         "temp_min": 27
#     },
#     "name": "Tsumeb",
#     "sys": {
#         "country": "NA",
#         "id": 6914,
#         "message": 0.0032,
#         "sunrise": 1541390781,
#         "sunset": 1541437154,
#         "type": 1
#     },
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 3.6
#     }
# }
